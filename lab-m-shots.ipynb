# %% [markdown]
# # M-Shots Learning

# %% [markdown]
# In this notebook, we'll explore small prompt engineering techniques and recommendations that will help us elicit responses from the models that are better suited to our needs.

# %%
from openai import OpenAI
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

OPENAI_API_KEY  = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# # Formatting the answer with Few Shot Samples.
#
# To obtain the model's response in a specific format, we have various options, but one of the most convenient is to use Few-Shot Samples. This involves presenting the model with pairs of user queries and example responses.
#
# Large models like GPT-3.5 respond well to the examples provided, adapting their response to the specified format.
#
# Depending on the number of examples given, this technique can be referred to as:
# * Zero-Shot.
# * One-Shot.
# * Few-Shots.
#
# With One Shot should be enough, and it is recommended to use a maximum of six shots. It's important to remember that this information is passed in each query and occupies space in the input prompt.

# %%
# Function to call the model.
def return_OAIResponse(user_message, context):
    client = OpenAI(
    # This is the default and can be omitted
    api_key=OPENAI_API_KEY,
)

    newcontext = context.copy()
    newcontext.append({'role':'user', 'content':"question: " + user_message})

    response = client.chat.completions.create(
            model="gpt-5.4-nano",
            messages=newcontext,
            temperature=1,
        )

    return (response.choices[0].message.content)

# %% [markdown]
# In this zero-shots prompt we obtain a correct response, but without formatting, as the model incorporates the information he wants.

# %%
#zero-shot
context_user = [
    {'role':'system', 'content':'You are an expert in F1.'}
]
print(return_OAIResponse("Who won the F1 2010?", context_user))
# Out:
# The **F1 2010 World Drivers’ Championship** was won by **Sebastian Vettel** (Red Bull Racing).

# %% [markdown]
# For a model as large and good as GPT 3.5, a single shot is enough to learn the output format we expect.

# %%
#one-shot
context_user = [
    {'role':'system', 'content':
     """You are an expert in F1.

     Who won the 2000 f1 championship?
     Driver: Michael Schumacher.
     Team: Ferrari."""}
]
print(return_OAIResponse("Who won the F1 2011?", context_user))
# Out:
# The **2011 Formula 1 World Championship** was won by **Sebastian Vettel**, driving for **Red Bull Racing**.

# %% [markdown]
# Smaller models, or more complicated formats, may require more than one shot. Here a sample with two shots.

# %%
#Few shots
context_user = [
    {'role':'system', 'content':
     """You are an expert in F1.

     Who won the 2010 f1 championship?
     Driver: Sebastian Vettel.
     Team: Red Bull Renault.

     Who won the 2009 f1 championship?
     Driver: Jenson Button.
     Team: BrawnGP."""}
]
print(return_OAIResponse("Who won the F1 2006?", context_user))
# Out:
# The **2006 Formula 1 World Championship** was won by **Fernando Alonso**, driving for **Renault**.

# %%
print(return_OAIResponse("Who won the F1 2019?", context_user))
# Out:
# The **2019 Formula 1 World Drivers’ Championship** was won by **Lewis Hamilton** (team: **Mercedes**).

# %% [markdown]
# We've been creating the prompt without using OpenAI's roles, and as we've seen, it worked correctly.
#
# However, the proper way to do this is by using these roles to construct the prompt, making the model's learning process even more effective.
#
# By not feeding it the entire prompt as if they were system commands, we enable the model to learn from a conversation, which is more realistic for it.

# %%
#Recomended solution
context_user = [
    {'role':'system', 'content':'You are and expert in f1.\n\n'},
    {'role':'user', 'content':'Who won the 2010 f1 championship?'},
    {'role':'assistant', 'content':"""Driver: Sebastian Vettel. \nTeam: Red Bull. \nPoints: 256. """},
    {'role':'user', 'content':'Who won the 2009 f1 championship?'},
    {'role':'assistant', 'content':"""Driver: Jenson Button. \nTeam: BrawnGP. \nPoints: 95. """},
]

print(return_OAIResponse("Who won the F1 2019?", context_user))
# Out:
# Lewis Hamilton won the **2019 Formula 1 World Championship** (for **Mercedes**).

# %% [markdown]
# We could also address it by using a more conventional prompt, describing what we want and how we want the format.
#
# However, it's essential to understand that in this case, the model is following instructions, whereas in the case of use shots, it is learning in real-time during inference.

# %%
context_user = [
    {'role':'system', 'content':"""You are and expert in f1.
    You are going to answer the question of the user giving the name of the rider,
    the name of the team and the points of the champion, following the format:
    Drive:
    Team:
    Points: """
    }
]

print(return_OAIResponse("Who won the F1 2019?", context_user))
# Out:
# Drive: Lewis Hamilton
# Team: Mercedes
# Points: 413

# %%
context_user = [
    {'role':'system', 'content':
     """You are classifying .

     Who won the 2010 f1 championship?
     Driver: Sebastian Vettel.
     Team: Red Bull Renault.

     Who won the 2009 f1 championship?
     Driver: Jenson Button.
     Team: BrawnGP."""}
]
print(return_OAIResponse("Who won the F1 2006?", context_user))
# Out:
# **2006 F1 Championship winner:** **Fernando Alonso** (Team: **Renault**).

# %% [markdown]
# Few Shots for classification.

# %%
context_user = [
    {'role':'system', 'content':
     """You are an expert in reviewing product opinions and classifying them as positive or negative.

     It fulfilled its function perfectly, I think the price is fair, I would buy it again.
     Sentiment: Positive

     It didn't work bad, but I wouldn't buy it again, maybe it's a bit expensive for what it does.
     Sentiment: Negative.

     I wouldn't know what to say, my son uses it, but he doesn't love it.
     Sentiment: Neutral
     """}
     
]
print(return_OAIResponse("I'm not going to return it, but I don't plan to buy it again.", context_user))
# Out:
# Sentiment: **Negative**

# %% [markdown]
# # Exercise
#  - Complete the prompts similar to what we did in class.
#      - Try at least 3 versions
#      - Be creative
#  - Write a one page report summarizing your findings.
#      - Were there variations that didn't work well? i.e., where GPT either hallucinated or wrong
#  - What did you learn?

# %%
# Function to call the model.
def return_OAIResponse(user_message, context):
    client = OpenAI(
        api_key=OPENAI_API_KEY,
    )

    newcontext = context.copy()
    newcontext.append(
        {'role':'user', 'content':"question: " + user_message}
    )

    response = client.chat.completions.create(
        model="gpt-5.4-nano",
        messages=newcontext,
        temperature=1,
    )

    return response.choices[0].message.content

# %%
#zero-shot
context_user = [
    {'role':'system', 'content':'You are an expert in colombian politics.'}
]
print(return_OAIResponse("Who was the President of Colombia in 2010?", context_user))
# Out:
# The President of Colombia in 2010 was **Álvaro Uribe Vélez**, who served from **2002 to 2010**.

# %%
#one-shot
context_user = [
    {'role':'system', 'content':
     """You are an expert in colombian politics.

     Who was the President of Colombia in 2000??
     President: Andres Pastrana.
     Party: Conservative Party."""}
]
print(return_OAIResponse("Who was the colombian politics 2011?", context_user))
# Out:
# In **2011**, the President of Colombia was **Juan Manuel Santos** (he was in office from **2010 to 2018**).

# %%
#Few shots
context_user = [
    {'role':'system', 'content':
     """You are an expert in colombian politics.

     Who was the 2009 colombian President?
     Presidnet: Alvaro Uribe.
     Party: Partido de la U.

     Who was the President of Colombia in 1999?
     President: Andres Pastrana.
     Party: Conservative."""}
]
print(return_OAIResponse("Who was president of Colombia in 2023?", context_user))
# Out:
# In 2023, the President of Colombia was **Gustavo Petro** (in office since **August 7, 2022**). His party is typically listed as **Pacto Histórico** (via **Partido Colombia Humana** and other allied movements within that coalition).

# %%
print(return_OAIResponse("Who was the colombian president in 1989?", context_user))
# Out:
# In **1989**, the President of Colombia was **Virgilio Barco Vargas** (from the **Liberal Party**).

# %% [markdown]
# ## 2 example

# %%
# Function to call the model.
def return_OAIResponse(user_message, context):
    client = OpenAI(
        api_key=OPENAI_API_KEY,
    )

    newcontext = context.copy()
    newcontext.append(
        {'role':'user', 'content':"question: " + user_message}
    )

    response = client.chat.completions.create(
        model="gpt-5.4-nano",
        messages=newcontext,
        temperature=1,
    )

    return response.choices[0].message.content

# %%
#zero-shot
context_user = [
    {'role':'system', 'content':'You are an expert in global Football'}
]
print(return_OAIResponse("Who was the top goal scorer of the Men's FIFA World Cup 2014?", context_user))
# Out:
# The top goal scorer of the **Men’s FIFA World Cup 2014** was **James Rodríguez (Colombia)**, who scored **6 goals**.

# %%
#one-shot
context_user = [
    {'role':'system', 'content':
     """You are an expert in global Football.

     Who was the top goal scorer of the Men's FIFA World Cup 2014?
     Player: James Rodríguez.
     Team: Colombia."""}
]
print(return_OAIResponse("Who was the top goal scorer of the Men's FIFA World Cup 2006?", context_user))
# Out:
# The top goal scorer of the **Men’s FIFA World Cup 2006** was **Miroslav Klose (Germany)**, who scored **5 goals**.

# %%
#Few shots
context_user = [
    {
        'role':'system',
        'content':"""
You are an expert in global football.

Who was the top goal scorer of the FIFA World Cup 2014?
Player: James Rodríguez.
Team: Colombia.
Goals: 6.

Who was the top goal scorer of the FIFA World Cup 2006?
Player: Miroslav Klose.
Team: Germany.
Goals: 5.
"""
    }
]
print(return_OAIResponse("Who was the top goal scorer of the Men's FIFA World Cup 2022?", context_user))
# Out:
# The top goal scorer of the **Men’s FIFA World Cup 2022** was **Kylian Mbappé (France)**, with **8 goals**.

# %%
print(return_OAIResponse("Who was the top goal scorer of the Men's FIFA World Cup 1966?", context_user))
# Out:
# The top goal scorer of the **Men’s FIFA World Cup 1966** was **Eusébio (Portugal)**, with **9 goals**.

# %% [markdown]
# ## 3rd example

# %%
# Function to call the model.
def return_OAIResponse(user_message, context):
    client = OpenAI(
        api_key=OPENAI_API_KEY,
    )

    newcontext = context.copy()
    newcontext.append(
        {'role':'user', 'content':"question: " + user_message}
    )

    response = client.chat.completions.create(
        model="gpt-5.4-nano",
        messages=newcontext,
        temperature=0,
    )

    return response.choices[0].message.content

# %%
#zero-shot
context_user = [
    {'role':'system', 'content':'You are an expert in Spanish football and La Liga.'}
]
print(return_OAIResponse("Who won La Liga title in 1999/2000 season?", context_user))
# Out:
# The **1999/2000 La Liga title** was won by **Real Madrid**.

# %%
#one-shot
context_user = [
    {'role':'system', 'content':
     """You are an expert in Spanish football and La Liga.

     Who won the title in 1999/2000 season?
     Team: Deportivo la Coruña.
     Runner-up:: Barcelona."""}
]
print(return_OAIResponse("Who won La Liga title in 2016/2017 season?", context_user))
# Out:
# The **2016/2017 La Liga title** was won by **Real Madrid**.

# %%
#Few shots
context_user = [
    {
        'role':'system',
        'content':"""
You are an expert in Spanish football and La Liga.

Who won La Liga title in 1999/2000 season?
Team: Deportivo la Coruña.
Runner-up:: Barcelona.

Who won La Liga title in 2002/2003 season?
Team: Real Madrid.
Runner-up:: Real Sociedad
"""
    }
]
print(return_OAIResponse("Who won La Liga title in 2013/2014 season?", context_user))
# Out:
# The **2013/2014 La Liga** title was won by **Real Madrid**.
